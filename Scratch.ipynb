# %%
from ensemble.compress import decompress
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from params import orig_height, orig_width
import cv2
import matplotlib
matplotlib.rcParams['figure.figsize'] = [20,20]

# %%
df_train = pd.read_csv('input/train_masks.csv')
ids_train = df_train['img'].map(lambda s: s.split('.')[0])

ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.1, random_state=42)

# %%
ids_train_split[:4]
# Out:
# 2218    69915dab0755_11
# 2034    61060ada97c9_03
# 3399    a7b9e343cf6b_08
# 2581    78bfb9c780db_06
# Name: img, dtype: object

# %%
for id in ids_train_split[1000:1005]:
    df = pd.read_pickle("ensemble/modelA/train/train_predictions/{}.pkl".format(id))
    mask = decompress(df, orig_height, orig_width)
#     mask[mask > .5] = 1
#     mask[mask < .5] = 0
    img = mpimg.imread('input/train_hq/{}.jpg'.format(id))
#     plt.imshow(img)
#     plt.show()
    mask3 = -np.expand_dims(mask, 3).repeat(3, axis=2)
    plt.imshow(img * mask3)
    plt.show()
# Out:
# /home/pl57/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   if __name__ == '__main__':

# %%
mask.mean()
# Out:
# 0.19733052141258331

# %%
mask3[400:410,570:580]
# Out:
# array([[[-0.99453127, -0.99453127, -0.99453127],
#         [-0.99519682, -0.99519682, -0.99519682],
#         [-0.99586236, -0.99586236, -0.99586236],
#         [-0.99652791, -0.99652791, -0.99652791],
#         [-0.99719346, -0.99719346, -0.99719346],
#         [-0.997859  , -0.997859  , -0.997859  ],
#         [-0.99852461, -0.99852461, -0.99852461],
#         [-0.99883014, -0.99883014, -0.99883014],
#         [-0.99889731, -0.99889731, -0.99889731],
#         [-0.99896455, -0.99896455, -0.99896455]],
#
#        [[-0.99524963, -0.99524963, -0.99524963],
#         [-0.9958176 , -0.9958176 , -0.9958176 ],
#         [-0.99638557, -0.99638557, -0.99638557],
#         [-0.99695361, -0.99695361, -0.99695361],
#         [-0.99752164, -0.99752164, -0.99752164],
#         [-0.99808955, -0.99808955, -0.99808955],
#         [-0.99865758, -0.99865758, -0.99865758],
#         [-0.99892086, -0.99892086, -0.99892086],
#         [-0.99898219, -0.99898219, -0.99898219],
#         [-0.99904364, -0.99904364, -0.99904364]],
#
#        [[-0.99596786, -0.99596786, -0.99596786],
#         [-0.99643838, -0.99643838, -0.99643838],
#         [-0.99690878, -0.99690878, -0.99690878],
#         [-0.9973793 , -0.9973793 , -0.9973793 ],
#         [-0.9978497 , -0.9978497 , -0.9978497 ],
#         [-0.99832016, -0.99832016, -0.99832016],
#         [-0.99879068, -0.99879068, -0.99879068],
#         [-0.99901152, -0.99901152, -0.99901152],
#         [-0.99906713, -0.99906713, -0.99906713],
#         [-0.99912274, -0.99912274, -0.99912274]],
#
#        [[-0.99668616, -0.99668616, -0.99668616],
#         [-0.99705911, -0.99705911, -0.99705911],
#         [-0.99743199, -0.99743199, -0.99743199],
#         [-0.99780488, -0.99780488, -0.99780488],
#         [-0.99817777, -0.99817777, -0.99817777],
#         [-0.99855077, -0.99855077, -0.99855077],
#         [-0.99892366, -0.99892366, -0.99892366],
#         [-0.99910223, -0.99910223, -0.99910223],
#         [-0.999152  , -0.999152  , -0.999152  ],
